# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

import math

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2
y2 = [math.exp(i) for i in x]

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x, y, label='linear')
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2

fig, axs = plt.subplots(nrows=1, ncols=2)
axs[0].plot(x, y)
axs[1].plot(x, z)
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, axs = plt.subplots(nrows=1, ncols=2, figsize= (11,5))
axs[0].plot(x, y)
axs[1].plot(x, z)
plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here

fig, axs = plt.subplots(nrows=1, ncols=2, figsize= (11,5))
axs[0].plot(x, y)
axs[1].plot(x, y2)

axs[0].set_yscale("linear")
axs[1].set_yscale("log")

plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

fig, axs = plt.subplots(nrows=1, ncols=2, figsize= (11,5))
axs[0].plot(x, y)
axs[1].plot(x, y2)

axs[0].set_yscale("linear")
axs[1].set_yscale("log")

axs[0].legend(['linear'])
axs[1].legend(['log'])

plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here

fitbit = pd.read_csv('../data/fitbit2.csv')
fitbit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        367 non-null    object
#  1   Calorie burned              367 non-null    int64
#  2   Steps                       367 non-null    int64
#  3   Distance                    367 non-null    float64
#  4   Floors                      367 non-null    int64
#  5   Minutes Sedentary           367 non-null    float64
#  6   Minutes Lightly Active      367 non-null    int64
#  7   Minutes Fairly Active       367 non-null    int64
#  8   Minutes Very Active         367 non-null    int64
#  9   Activity Calories           367 non-null    int64
#  10  MinutesOfSleep              367 non-null    int64
#  11  MinutesOfBeingAwake         367 non-null    int64
#  12  NumberOfAwakings            367 non-null    int64
# ...

# %%
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize= (12,4))

# MEDIAN STEPS BY MONTH_ENCODED
# your coode here

fitbit_m = fitbit.loc[:, ['Steps','Months_encoded']]
fitbit_m = fitbit_m.groupby(by="Months_encoded").mean()

plt.sca(axs[0])
axs[0].plot(fitbit_m.index.values, fitbit_m['Steps'])

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

fitbit_w = fitbit.loc[:, ['Steps','Work_or_Weekend']]
fitbit_w = fitbit_w.groupby(by="Work_or_Weekend").mean()

plt.sca(axs[1])
axs[1].plot(fitbit_w.index.values, fitbit_w['Steps'])

plt.savefig('../figures/mean_by_month_and_mean_by_work_or_weekend.png')
plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

for e in fitbit.columns[5:8]:
    fitbit.plot.scatter(x=e, y='Steps')

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

titanic = pd.read_csv('../data/titanic.csv')
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Gender       1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        1309 non-null   object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

titanic.select_dtypes(include=['int64','float64']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Age          1309 non-null   float64
#  4   SibSp        1309 non-null   int64
#  5   Parch        1309 non-null   int64
#  6   Fare         1309 non-null   float64
# dtypes: float64(3), int64(4)
# memory usage: 71.7 KB

# %%
# CATEGORICAL VARIABLES
# your code here

titanic.select_dtypes(include=['object']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      1309 non-null   object
#  1   Gender    1309 non-null   object
#  2   Ticket    1309 non-null   object
#  3   Cabin     1309 non-null   object
#  4   Embarked  1309 non-null   object
# dtypes: object(5)
# memory usage: 51.3+ KB

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

plt.style.use('classic')
plt.rcParams['figure.figsize']=(12, 6)

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

plt.hist(titanic['Age'])
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

fig, ax = plt.subplots(nrows=1, ncols=3)

ax[0].hist(titanic['Age'], bins=10, color='blue')
ax[1].hist(titanic['Age'], bins=20, color='red')
ax[2].hist(titanic['Age'], bins=50, color='green')
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
Affects the readability of the plots
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

sns.histplot(titanic['Age'])
plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

#titanic['Gender'].count()

fig, ax = plt.subplots(nrows=1, ncols=1)
plt.pie(titanic['Gender'].value_counts())
plt.legend(labels=['Male','Female'],frameon=False)
plt.title('Gender distribution');
plt.show()

# %%
# Method 2 - seaborn
# your code here

sns.countplot(x=titanic["Gender"])
plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

sns.countplot(x=titanic["Pclass"])
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

ax = sns.boxplot(x=titanic['Age'], showmeans=True)
ax.axvline(x=titanic['Age'].median(), color='g', linestyle='-', label='Median')
ax.axvline(x=titanic['Age'].mean(), color='r', linestyle='-', label='Mean')
ax.legend(loc='best')

plt.show()

# %%
"""

I used a boxplot because it gives us the distribution of passengers by age, 
dividing the information by quartiles, the median and the outlier values.

"""
# Out:
# '\n\nI used a boxplot because it gives us the distribution of passengers by age, \ndividing the information by quartiles, the median and the outlier values.\n\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""

- The distribution is slightly asymmetric, seeing how the majority of passengers are older than the median
- The age of the passengers is concentrated between 20 and 40 years approximately
- Passengers over 60 years of age are specific cases (outliers)

"""
# Out:
# '\n\n- The distribution is slightly asymmetric, seeing how the majority of passengers are older than the median\n- The age of the passengers is concentrated between 20 and 40 years approximately\n- Passengers over 60 years of age are specific cases (outliers)\n\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

ax = sns.histplot(x=titanic['Age'])
ax.axvline(x=titanic['Age'].median(), color='g', linestyle='-', label='Median')
ax.axvline(x=titanic['Age'].mean(), color='r', linestyle='-', label='Mean')
ax.legend(loc='best')

plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
Number of persons by age more clearly than using a boxplot
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

plt.scatter(data=titanic, 
            x='Age', 
            y='Fare')
plt.show()

# %%
# Method 2 - seaborn
# your code here

sns.scatterplot(data=titanic, x="Age", y="Fare")
plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

corr = titanic.corr(numeric_only=True)
sns.heatmap(corr, cmap='coolwarm', annot=True)
plt.show()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""

SibSp and Parch (Positive correlation)
Alone and Parch (Negative correlation)
Alone and SibSp (Negative correlation)

"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

sns.boxplot(data=titanic, x='Pclass', y='Age')
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here

g = sns.FacetGrid(titanic, col='Gender')
g.map(plt.hist, 'Age')
plt.show()
